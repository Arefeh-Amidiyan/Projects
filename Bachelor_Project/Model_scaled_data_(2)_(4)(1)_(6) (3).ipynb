# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# file_path = '/content/drive/MyDrive/saderat_bank.csv'

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
df = pd.read_csv('/content/saderat_bank.csv')

# %%
df
# Out:
#           <TICKER>  <DTYYYYMMDD>  <FIRST>  <HIGH>   <LOW>  <CLOSE>  \
# 0     Saderat Bank      20241126   1962.0  1962.0  1850.0   1930.0
# 1     Saderat Bank      20241125   1905.0  1905.0  1873.0   1905.0
# 2     Saderat Bank      20241124   1829.0  1851.0  1815.0   1850.0
# 3     Saderat Bank      20241123   1770.0  1801.0  1749.0   1798.0
# 4     Saderat Bank      20241120   1746.0  1788.0  1746.0   1749.0
# ...            ...           ...      ...     ...     ...      ...
# 3731  Saderat Bank      20090614   1019.0  1026.0  1019.0   1024.0
# 3732  Saderat Bank      20090613   1013.0  1025.0  1006.0   1023.0
# 3733  Saderat Bank      20090610   1031.0  1031.0  1020.0   1021.0
# 3734  Saderat Bank      20090609   1002.0  1002.0  1001.0   1001.0
# 3735  Saderat Bank      20090608      0.0     0.0     0.0   1000.0
#
#            <VALUE>      <VOL>  <OPENINT> <PER>  <OPEN>  <LAST>
# 0     1.319969e+12  684058039       7853     D  1905.0  1865.0
# 1     5.028978e+11  263993639       2426     D  1850.0  1905.0
# 2     4.475030e+11  241896657       2161     D  1798.0  1851.0
# 3     5.691964e+11  316643947       3671     D  1749.0  1801.0
# 4     4.129098e+11  236049692       2826     D  1800.0  1746.0
# ...            ...        ...        ...   ...     ...     ...
# 3731  4.085443e+10   39890423       1995     D  1023.0  1025.0
# 3732  1.234601e+11  120700223       5411     D  1021.0  1024.0
# 3733  5.489370e+10   53760812       2406     D  1001.0  1025.0
# 3734  9.834886e+11  982499500        545     D  1001.0  1001.0
# 3735  0.000000e+00          0          0     D  1000.0  1000.0
#
# [3736 rows x 12 columns]

# %%
df = df.drop(['<TICKER>'], axis=1)

# %%
df = df.rename(columns={'<DTYYYYMMDD>': 'date', '<HIGH>': 'high','<FIRST>' : 'first', '<LOW>': 'low', '<CLOSE>': 'close', '<VALUE>': 'value',
                        '<VOL>': 'vol', '<OPENINT>': 'openint','<PER>': 'per', '<OPEN>': 'open', '<LAST>': 'last'})

# %%
df
# Out:
#           date   first    high     low   close         value        vol  \
# 0     20241126  1962.0  1962.0  1850.0  1930.0  1.319969e+12  684058039
# 1     20241125  1905.0  1905.0  1873.0  1905.0  5.028978e+11  263993639
# 2     20241124  1829.0  1851.0  1815.0  1850.0  4.475030e+11  241896657
# 3     20241123  1770.0  1801.0  1749.0  1798.0  5.691964e+11  316643947
# 4     20241120  1746.0  1788.0  1746.0  1749.0  4.129098e+11  236049692
# ...        ...     ...     ...     ...     ...           ...        ...
# 3731  20090614  1019.0  1026.0  1019.0  1024.0  4.085443e+10   39890423
# 3732  20090613  1013.0  1025.0  1006.0  1023.0  1.234601e+11  120700223
# 3733  20090610  1031.0  1031.0  1020.0  1021.0  5.489370e+10   53760812
# 3734  20090609  1002.0  1002.0  1001.0  1001.0  9.834886e+11  982499500
# 3735  20090608     0.0     0.0     0.0  1000.0  0.000000e+00          0
#
#       openint per    open    last
# 0        7853   D  1905.0  1865.0
# 1        2426   D  1850.0  1905.0
# 2        2161   D  1798.0  1851.0
# 3        3671   D  1749.0  1801.0
# 4        2826   D  1800.0  1746.0
# ...       ...  ..     ...     ...
# 3731     1995   D  1023.0  1025.0
# 3732     5411   D  1021.0  1024.0
# 3733     2406   D  1001.0  1025.0
# 3734      545   D  1001.0  1001.0
# 3735        0   D  1000.0  1000.0
#
# [3736 rows x 11 columns]

# %% [markdown]
# درصد تغییرات

# %%
df['percentage_change'] = df['close'].pct_change() * 100
# df['percentage_change'] = ((df['last'] - df['first']) / df['first']) * 100

# %%
df
# Out:
#           date   first    high     low   close         value        vol  \
# 0     20241126  1962.0  1962.0  1850.0  1930.0  1.319969e+12  684058039
# 1     20241125  1905.0  1905.0  1873.0  1905.0  5.028978e+11  263993639
# 2     20241124  1829.0  1851.0  1815.0  1850.0  4.475030e+11  241896657
# 3     20241123  1770.0  1801.0  1749.0  1798.0  5.691964e+11  316643947
# 4     20241120  1746.0  1788.0  1746.0  1749.0  4.129098e+11  236049692
# ...        ...     ...     ...     ...     ...           ...        ...
# 3731  20090614  1019.0  1026.0  1019.0  1024.0  4.085443e+10   39890423
# 3732  20090613  1013.0  1025.0  1006.0  1023.0  1.234601e+11  120700223
# 3733  20090610  1031.0  1031.0  1020.0  1021.0  5.489370e+10   53760812
# 3734  20090609  1002.0  1002.0  1001.0  1001.0  9.834886e+11  982499500
# 3735  20090608     0.0     0.0     0.0  1000.0  0.000000e+00          0
#
#       openint per    open    last  percentage_change
# 0        7853   D  1905.0  1865.0                NaN
# 1        2426   D  1850.0  1905.0          -1.295337
# 2        2161   D  1798.0  1851.0          -2.887139
# 3        3671   D  1749.0  1801.0          -2.810811
# 4        2826   D  1800.0  1746.0          -2.725250
# ...       ...  ..     ...     ...                ...
# 3731     1995   D  1023.0  1025.0          -0.097561
# 3732     5411   D  1021.0  1024.0          -0.097656
# 3733     2406   D  1001.0  1025.0          -0.195503
# 3734      545   D  1001.0  1001.0          -1.958864
# 3735        0   D  1000.0  1000.0          -0.099900
#
# [3736 rows x 12 columns]

# %% [markdown]
# شمردن داپلیکیت ها

# %%
total_duplicates = df.duplicated().sum()
print(f'Total number of duplicates are {total_duplicates}')
# Out:
# Total number of duplicates are 0

# %% [markdown]
# جمع خالی ها

# %%
df.isnull().sum()
# Out:
# date                 0
# first                0
# high                 0
# low                  0
# close                0
# value                0
# vol                  0
# openint              0
# per                  0
# open                 0
# last                 0
# percentage_change    1
# dtype: int64

# %%
df['percentage_change'].iloc[0] = 0  # جایگزینی فقط برای مقدار اول
# Out:
# <ipython-input-13-8d015b393aad>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['percentage_change'].iloc[0] = 0  # جایگزینی فقط برای مقدار اول
# <ipython-input-13-8d015b393aad>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['percentage_change'].iloc[0] = 0  # جایگزینی فقط برای مقدار اول

# %%
df.head()
# Out:
#        date   first    high     low   close         value        vol  openint  \
# 0  20241126  1962.0  1962.0  1850.0  1930.0  1.319969e+12  684058039     7853
# 1  20241125  1905.0  1905.0  1873.0  1905.0  5.028978e+11  263993639     2426
# 2  20241124  1829.0  1851.0  1815.0  1850.0  4.475030e+11  241896657     2161
# 3  20241123  1770.0  1801.0  1749.0  1798.0  5.691964e+11  316643947     3671
# 4  20241120  1746.0  1788.0  1746.0  1749.0  4.129098e+11  236049692     2826
#
#   per    open    last  percentage_change
# 0   D  1905.0  1865.0           0.000000
# 1   D  1850.0  1905.0          -1.295337
# 2   D  1798.0  1851.0          -2.887139
# 3   D  1749.0  1801.0          -2.810811
# 4   D  1800.0  1746.0          -2.725250

# %%
# Converting 'Volume' from strings with 'M' and 'B' to numerical values
df['vol'] = df['vol'].replace({'M': '*1e6', 'B': '*1e9'}, regex=True).map(pd.eval).astype(float)

# %%
# تبدیل تاریخ به فرمت datetime
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3736 entries, 0 to 3735
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               3736 non-null   datetime64[ns]
#  1   first              3736 non-null   float64
#  2   high               3736 non-null   float64
#  3   low                3736 non-null   float64
#  4   close              3736 non-null   float64
#  5   value              3736 non-null   float64
#  6   vol                3736 non-null   float64
#  7   openint            3736 non-null   int64
#  8   per                3736 non-null   object
#  9   open               3736 non-null   float64
#  10  last               3736 non-null   float64
#  11  percentage_change  3736 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int64(1), object(1)
# memory usage: 350.4+ KB

# %% [markdown]
# Since Date is string (object) type, we convert it to datetime.

# %%
df.describe()
# Out:
#                                 date        first         high          low  \
# count                           3736  3736.000000  3736.000000  3736.000000
# mean   2017-02-22 17:03:43.554604032  1177.256692  1194.509636  1155.486349
# min              2009-06-08 00:00:00     0.000000     0.000000     0.000000
# 25%              2013-04-21 18:00:00   745.750000   751.750000   725.000000
# 50%              2017-02-14 12:00:00  1079.000000  1088.000000  1060.000000
# 75%              2020-12-28 06:00:00  1653.000000  1683.250000  1630.000000
# max              2024-11-26 00:00:00  5070.000000  5110.000000  4630.000000
# std                              NaN   832.393075   850.284748   812.790357
#
#              close         value           vol        openint         open  \
# count  3736.000000  3.736000e+03  3.736000e+03    3736.000000  3736.000000
# mean   1375.385171  2.304919e+11  1.143582e+08    3716.648019  1374.232602
# min     391.000000  0.000000e+00  0.000000e+00       0.000000   391.000000
# 25%    1001.000000  9.608347e+08  8.180528e+05      72.750000  1001.000000
# 50%    1110.000000  2.838320e+10  2.898921e+07    1212.500000  1110.000000
# 75%    1692.000000  1.472216e+11  1.104734e+08    3755.500000  1690.250000
# max    4870.000000  1.049525e+13  2.858086e+09  126055.000000  4870.000000
# std     679.162044  7.127002e+11  2.422939e+08    8352.457933   679.190495
#
#               last  percentage_change
# count  3736.000000        3736.000000
# mean   1371.850375           0.052162
# min     393.000000         -13.085938
# 25%     979.000000          -0.501316
# 50%    1111.000000           0.000000
# 75%    1690.000000           0.569072
# max    4840.000000         203.580563
# std     679.922115           4.906121

# %% [markdown]
# missing_values

# %%
# Checking for any missing values in the dataset
missing_values = df.isnull().sum()
missing_values
# Out:
# date                 0
# first                0
# high                 0
# low                  0
# close                0
# value                0
# vol                  0
# openint              0
# per                  0
# open                 0
# last                 0
# percentage_change    0
# dtype: int64

# %%
df.tail()
# Out:
#            date   first    high     low   close         value          vol  \
# 3731 2009-06-14  1019.0  1026.0  1019.0  1024.0  4.085443e+10   39890423.0
# 3732 2009-06-13  1013.0  1025.0  1006.0  1023.0  1.234601e+11  120700223.0
# 3733 2009-06-10  1031.0  1031.0  1020.0  1021.0  5.489370e+10   53760812.0
# 3734 2009-06-09  1002.0  1002.0  1001.0  1001.0  9.834886e+11  982499500.0
# 3735 2009-06-08     0.0     0.0     0.0  1000.0  0.000000e+00          0.0
#
#       openint per    open    last  percentage_change
# 3731     1995   D  1023.0  1025.0          -0.097561
# 3732     5411   D  1021.0  1024.0          -0.097656
# 3733     2406   D  1001.0  1025.0          -0.195503
# 3734      545   D  1001.0  1001.0          -1.958864
# 3735        0   D  1000.0  1000.0          -0.099900

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import matplotlib.dates as mdates


# # مرتب‌سازی بر اساس تاریخ (در صورت نیاز)
# df = df.sort_values('date')

# # رسم نمودار قیمت برحسب تاریخ
# plt.figure(figsize=(12, 6))
# plt.plot(df['date'], df['close'], label='Closing Price', color='blue')

# # تنظیمات برای محور تاریخ
# plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # نمایش تاریخ به‌صورت سالانه
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # فرمت سال
# plt.gca().xaxis.set_minor_locator(mdates.MonthLocator())  # نمایش ماه‌ها به‌عنوان minor ticks

# # چرخش و تنظیم محور x
# plt.xticks(rotation=0)
# plt.title('Bank Saderat: Closing Price Analysis Over Time')
# plt.xlabel('Date')
# plt.ylabel('Closing Price')
# plt.legend()
# plt.grid()
# plt.tight_layout()
# plt.show()

# %% [markdown]
# پلات توزیع درصد تغییرات

# %%
# تبدیل ستون تاریخ به نوع datetime
df['date'] = pd.to_datetime(df['date'])

# مرتب‌سازی بر اساس تاریخ از 2009 تا 2024
df = df.sort_values(by='date', ascending=True)

# نمایش چند ردیف اول از داده‌های مرتب‌شده
df.head()
# Out:
#            date   first    high     low   close         value          vol  \
# 3735 2009-06-08     0.0     0.0     0.0  1000.0  0.000000e+00          0.0
# 3734 2009-06-09  1002.0  1002.0  1001.0  1001.0  9.834886e+11  982499500.0
# 3733 2009-06-10  1031.0  1031.0  1020.0  1021.0  5.489370e+10   53760812.0
# 3732 2009-06-13  1013.0  1025.0  1006.0  1023.0  1.234601e+11  120700223.0
# 3731 2009-06-14  1019.0  1026.0  1019.0  1024.0  4.085443e+10   39890423.0
#
#       openint per    open    last  percentage_change
# 3735        0   D  1000.0  1000.0          -0.099900
# 3734      545   D  1001.0  1001.0          -1.958864
# 3733     2406   D  1001.0  1025.0          -0.195503
# 3732     5411   D  1021.0  1024.0          -0.097656
# 3731     1995   D  1023.0  1025.0          -0.097561

# %% [markdown]
# heatmap

# %% [markdown]
# تجزیه و تحلیل روند و فصلی بودن داده‌های قیمت بسته شدن

# %%
# Trend and Seasonality
from statsmodels.tsa.seasonal import seasonal_decompose

# Decompose the Closing Price
decomposition = seasonal_decompose(df['close'], model='additive', period=30)  # assuming monthly seasonality

fig = decomposition.plot()
plt.show()

# %% [markdown]
# شناخت داده های پرت

# %%
# Outlier Detection using Z-Score
from scipy import stats
import numpy as np

z_scores = np.abs(stats.zscore(df['close']))
threshold = 3
outliers = np.where(z_scores > threshold)
print(f"Number of outliers in Closing Price: {len(outliers[0])}")
# Out:
# Number of outliers in Closing Price: 86

# %%
# # محاسبه میانگین قیمت بسته شدن
# mean_close = df['close'].mean(

# # جایگزینی داده‌های پرت با میانگین
# df['close'] = np.where(np.abs(stats.zscore(df['close'])) > 3, mean_close, df['close'])

# # نمایش دیتاست پس از جایگزینی
# print(f"Number of rows after replacing outliers with mean: {df.shape[0]}")

# %% [markdown]
# ### Scaling

# %%
df
# Out:
#            date   first    high     low   close         value          vol  \
# 3735 2009-06-08     0.0     0.0     0.0  1000.0  0.000000e+00          0.0
# 3734 2009-06-09  1002.0  1002.0  1001.0  1001.0  9.834886e+11  982499500.0
# 3733 2009-06-10  1031.0  1031.0  1020.0  1021.0  5.489370e+10   53760812.0
# 3732 2009-06-13  1013.0  1025.0  1006.0  1023.0  1.234601e+11  120700223.0
# 3731 2009-06-14  1019.0  1026.0  1019.0  1024.0  4.085443e+10   39890423.0
# ...         ...     ...     ...     ...     ...           ...          ...
# 4    2024-11-20  1746.0  1788.0  1746.0  1749.0  4.129098e+11  236049692.0
# 3    2024-11-23  1770.0  1801.0  1749.0  1798.0  5.691964e+11  316643947.0
# 2    2024-11-24  1829.0  1851.0  1815.0  1850.0  4.475030e+11  241896657.0
# 1    2024-11-25  1905.0  1905.0  1873.0  1905.0  5.028978e+11  263993639.0
# 0    2024-11-26  1962.0  1962.0  1850.0  1930.0  1.319969e+12  684058039.0
#
#       openint per    open    last  percentage_change
# 3735        0   D  1000.0  1000.0          -0.099900
# 3734      545   D  1001.0  1001.0          -1.958864
# 3733     2406   D  1001.0  1025.0          -0.195503
# 3732     5411   D  1021.0  1024.0          -0.097656
# 3731     1995   D  1023.0  1025.0          -0.097561
# ...       ...  ..     ...     ...                ...
# 4        2826   D  1800.0  1746.0          -2.725250
# 3        3671   D  1749.0  1801.0          -2.810811
# 2        2161   D  1798.0  1851.0          -2.887139
# 1        2426   D  1850.0  1905.0          -1.295337
# 0        7853   D  1905.0  1865.0           0.000000
#
# [3736 rows x 12 columns]

# %%
# Scaling the numerical features using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

# Selecting features for scaling (excluding Date and Percentage Change as it is in percentage form)
features_to_scale = ['close', 'open', 'high', 'low', 'vol']

# Initializing the scaler
scaler = MinMaxScaler()

# Scaling the selected features
df[features_to_scale] = scaler.fit_transform(df[features_to_scale])

# Displaying the first few rows to verify scaling
df[['date', 'close', 'open', 'high', 'low', 'vol']].head()
# Out:
#            date     close      open      high       low       vol
# 3735 2009-06-08  0.135968  0.135968  0.000000  0.000000  0.000000
# 3734 2009-06-09  0.136191  0.136191  0.196086  0.216199  0.343761
# 3733 2009-06-10  0.140656  0.136191  0.201761  0.220302  0.018810
# 3732 2009-06-13  0.141103  0.140656  0.200587  0.217279  0.042231
# 3731 2009-06-14  0.141326  0.141103  0.200783  0.220086  0.013957

# %%
# Print date range of the dataset
print('Date Range:', df['date'].min(), 'to', df['date'].max())
# Out:
# Date Range: 2009-06-08 00:00:00 to 2024-11-26 00:00:00

# %%
# Feature Engineering

# Moving Averages
df['MA10'] = df['close'].rolling(window=10).mean()
df['MA50'] = df['close'].rolling(window=50).mean()

# Lag Features
for lag in range(1, 6):
    df[f'Lag_{lag}'] = df['close'].shift(lag)

# Volatility (Standard Deviation)
df['Volatility'] = df['close'].rolling(window=10).std()

# Drop rows with NaN values generated by feature engineering
df.dropna(inplace=True)

print(df.head())
# Out:
#            date  first      high       low     close         value       vol  \
# 3686 2009-08-19  963.0  0.191389  0.207991  0.131503  3.055110e+08  0.000110
# 3685 2009-08-22  970.0  0.189824  0.207775  0.131279  4.754206e+08  0.000172
# 3684 2009-08-23  970.0  0.189824  0.205616  0.130610  1.180368e+09  0.000430
# 3683 2009-08-24  964.0  0.189041  0.206048  0.130163  9.687572e+08  0.000353
# 3682 2009-08-25  960.0  0.188063  0.206263  0.129716  7.652826e+08  0.000279
#
#       openint per      open   last  percentage_change      MA10      MA50  \
# 3686       32   D  0.131503  965.0           0.102145  0.131815  0.141040
# 3685       53   D  0.131503  966.0           0.307377  0.131547  0.140947
# 3684       74   D  0.131279  960.0           0.205339  0.131302  0.140835
# 3683       62   D  0.130610  960.0           0.205761  0.131190  0.140625
# 3682       49   D  0.130163  955.0           0.206186  0.131101  0.140397
#
#          Lag_1     Lag_2     Lag_3     Lag_4     Lag_5  Volatility
# 3686  0.131503  0.131726  0.131726  0.131503  0.131279    0.000971
# 3685  0.131503  0.131503  0.131726  0.131726  0.131503    0.000621
# 3684  0.131279  0.131503  0.131503  0.131726  0.131726    0.000400
# 3683  0.130610  0.131279  0.131503  0.131503  0.131726    0.000539
# 3682  0.130163  0.130610  0.131279  0.131503  0.131503    0.000697

# %% [markdown]
# ### Model selection

# %%
# import pandas as pd

# %%
# df.to_csv('/content/Stock_BSDR1.csv', index=False)

# %%
# df = pd.read_csv('/content/Stock_BSDR1.csv')
# df.head()

# %%
df.tail()
# Out:
#         date   first      high       low     close         value       vol  \
# 4 2024-11-20  1746.0  0.349902  0.377106  0.303193  4.129098e+11  0.082590
# 3 2024-11-23  1770.0  0.352446  0.377754  0.314133  5.691964e+11  0.110789
# 2 2024-11-24  1829.0  0.362231  0.392009  0.325742  4.475030e+11  0.084636
# 1 2024-11-25  1905.0  0.372798  0.404536  0.338022  5.028978e+11  0.092367
# 0 2024-11-26  1962.0  0.383953  0.399568  0.343603  1.319969e+12  0.239341
#
#    openint per      open    last  percentage_change      MA10      MA50  \
# 4     2826   D  0.314579  1746.0          -2.725250  0.287453  0.281692
# 3     3671   D  0.303193  1801.0          -2.810811  0.292990  0.282559
# 2     2161   D  0.314133  1851.0          -2.887139  0.298660  0.283813
# 1     2426   D  0.325742  1905.0          -1.295337  0.304577  0.285416
# 0     7853   D  0.338022  1865.0           0.000000  0.311186  0.287136
#
#       Lag_1     Lag_2     Lag_3     Lag_4     Lag_5  Volatility
# 4  0.314579  0.305649  0.294262  0.291806  0.280866    0.017507
# 3  0.303193  0.314579  0.305649  0.294262  0.291806    0.016126
# 2  0.314133  0.303193  0.314579  0.305649  0.294262    0.016726
# 1  0.325742  0.314133  0.303193  0.314579  0.305649    0.019221
# 0  0.338022  0.325742  0.314133  0.303193  0.314579    0.020218

# %%
# بررسی مقادیر نامعتبر (NaT) پس از تبدیل به datetime
invalid_dates = df['date'].isna().sum()
print(f"Number of invalid dates: {invalid_dates}")
# Out:
# Number of invalid dates: 0

# %%
# نمایش چند نمونه از ردیف‌هایی که تاریخ آنها نامعتبر است
print(df[df['date'].isna()])
# Out:
# Empty DataFrame
# Columns: [date, first, high, low, close, value, vol, openint, per, open, last, percentage_change, MA10, MA50, Lag_1, Lag_2, Lag_3, Lag_4, Lag_5, Volatility]
# Index: []

# %%
df = df.dropna(subset=['date'])
df
# Out:
#            date   first      high       low     close         value       vol  \
# 3686 2009-08-19   963.0  0.191389  0.207991  0.131503  3.055110e+08  0.000110
# 3685 2009-08-22   970.0  0.189824  0.207775  0.131279  4.754206e+08  0.000172
# 3684 2009-08-23   970.0  0.189824  0.205616  0.130610  1.180368e+09  0.000430
# 3683 2009-08-24   964.0  0.189041  0.206048  0.130163  9.687572e+08  0.000353
# 3682 2009-08-25   960.0  0.188063  0.206263  0.129716  7.652826e+08  0.000279
# ...         ...     ...       ...       ...       ...           ...       ...
# 4    2024-11-20  1746.0  0.349902  0.377106  0.303193  4.129098e+11  0.082590
# 3    2024-11-23  1770.0  0.352446  0.377754  0.314133  5.691964e+11  0.110789
# 2    2024-11-24  1829.0  0.362231  0.392009  0.325742  4.475030e+11  0.084636
# 1    2024-11-25  1905.0  0.372798  0.404536  0.338022  5.028978e+11  0.092367
# 0    2024-11-26  1962.0  0.383953  0.399568  0.343603  1.319969e+12  0.239341
#
#       openint per      open    last  percentage_change      MA10      MA50  \
# 3686       32   D  0.131503   965.0           0.102145  0.131815  0.141040
# 3685       53   D  0.131503   966.0           0.307377  0.131547  0.140947
# 3684       74   D  0.131279   960.0           0.205339  0.131302  0.140835
# 3683       62   D  0.130610   960.0           0.205761  0.131190  0.140625
# 3682       49   D  0.130163   955.0           0.206186  0.131101  0.140397
# ...       ...  ..       ...     ...                ...       ...       ...
# 4        2826   D  0.314579  1746.0          -2.725250  0.287453  0.281692
# 3        3671   D  0.303193  1801.0          -2.810811  0.292990  0.282559
# 2        2161   D  0.314133  1851.0          -2.887139  0.298660  0.283813
# 1        2426   D  0.325742  1905.0          -1.295337  0.304577  0.285416
# 0        7853   D  0.338022  1865.0           0.000000  0.311186  0.287136
#
#          Lag_1     Lag_2     Lag_3     Lag_4     Lag_5  Volatility
# 3686  0.131503  0.131726  0.131726  0.131503  0.131279    0.000971
# 3685  0.131503  0.131503  0.131726  0.131726  0.131503    0.000621
# 3684  0.131279  0.131503  0.131503  0.131726  0.131726    0.000400
# 3683  0.130610  0.131279  0.131503  0.131503  0.131726    0.000539
# 3682  0.130163  0.130610  0.131279  0.131503  0.131503    0.000697
# ...        ...       ...       ...       ...       ...         ...
# 4     0.314579  0.305649  0.294262  0.291806  0.280866    0.017507
# 3     0.303193  0.314579  0.305649  0.294262  0.291806    0.016126
# 2     0.314133  0.303193  0.314579  0.305649  0.294262    0.016726
# 1     0.325742  0.314133  0.303193  0.314579  0.305649    0.019221
# 0     0.338022  0.325742  0.314133  0.303193  0.314579    0.020218
#
# [3687 rows x 20 columns]

# %%
# Sort the data by 'Date' in ascending order
# df['date'] = pd.to_datetime(df['date'])
# df = df.sort_values(by='date').reset_index(drop=False)

df.reset_index(inplace= True)
df.drop(columns = ['index'], inplace= True)
df
# Out:
#            date   first      high       low     close         value       vol  \
# 0    2009-08-19   963.0  0.191389  0.207991  0.131503  3.055110e+08  0.000110
# 1    2009-08-22   970.0  0.189824  0.207775  0.131279  4.754206e+08  0.000172
# 2    2009-08-23   970.0  0.189824  0.205616  0.130610  1.180368e+09  0.000430
# 3    2009-08-24   964.0  0.189041  0.206048  0.130163  9.687572e+08  0.000353
# 4    2009-08-25   960.0  0.188063  0.206263  0.129716  7.652826e+08  0.000279
# ...         ...     ...       ...       ...       ...           ...       ...
# 3682 2024-11-20  1746.0  0.349902  0.377106  0.303193  4.129098e+11  0.082590
# 3683 2024-11-23  1770.0  0.352446  0.377754  0.314133  5.691964e+11  0.110789
# 3684 2024-11-24  1829.0  0.362231  0.392009  0.325742  4.475030e+11  0.084636
# 3685 2024-11-25  1905.0  0.372798  0.404536  0.338022  5.028978e+11  0.092367
# 3686 2024-11-26  1962.0  0.383953  0.399568  0.343603  1.319969e+12  0.239341
#
#       openint per      open    last  percentage_change      MA10      MA50  \
# 0          32   D  0.131503   965.0           0.102145  0.131815  0.141040
# 1          53   D  0.131503   966.0           0.307377  0.131547  0.140947
# 2          74   D  0.131279   960.0           0.205339  0.131302  0.140835
# 3          62   D  0.130610   960.0           0.205761  0.131190  0.140625
# 4          49   D  0.130163   955.0           0.206186  0.131101  0.140397
# ...       ...  ..       ...     ...                ...       ...       ...
# 3682     2826   D  0.314579  1746.0          -2.725250  0.287453  0.281692
# 3683     3671   D  0.303193  1801.0          -2.810811  0.292990  0.282559
# 3684     2161   D  0.314133  1851.0          -2.887139  0.298660  0.283813
# 3685     2426   D  0.325742  1905.0          -1.295337  0.304577  0.285416
# 3686     7853   D  0.338022  1865.0           0.000000  0.311186  0.287136
#
#          Lag_1     Lag_2     Lag_3     Lag_4     Lag_5  Volatility
# 0     0.131503  0.131726  0.131726  0.131503  0.131279    0.000971
# 1     0.131503  0.131503  0.131726  0.131726  0.131503    0.000621
# 2     0.131279  0.131503  0.131503  0.131726  0.131726    0.000400
# 3     0.130610  0.131279  0.131503  0.131503  0.131726    0.000539
# 4     0.130163  0.130610  0.131279  0.131503  0.131503    0.000697
# ...        ...       ...       ...       ...       ...         ...
# 3682  0.314579  0.305649  0.294262  0.291806  0.280866    0.017507
# 3683  0.303193  0.314579  0.305649  0.294262  0.291806    0.016126
# 3684  0.314133  0.303193  0.314579  0.305649  0.294262    0.016726
# 3685  0.325742  0.314133  0.303193  0.314579  0.305649    0.019221
# 3686  0.338022  0.325742  0.314133  0.303193  0.314579    0.020218
#
# [3687 rows x 20 columns]

# %%
df.head()
# Out:
#         date  first      high       low     close         value       vol  \
# 0 2009-08-19  963.0  0.191389  0.207991  0.131503  3.055110e+08  0.000110
# 1 2009-08-22  970.0  0.189824  0.207775  0.131279  4.754206e+08  0.000172
# 2 2009-08-23  970.0  0.189824  0.205616  0.130610  1.180368e+09  0.000430
# 3 2009-08-24  964.0  0.189041  0.206048  0.130163  9.687572e+08  0.000353
# 4 2009-08-25  960.0  0.188063  0.206263  0.129716  7.652826e+08  0.000279
#
#    openint per      open   last  percentage_change      MA10      MA50  \
# 0       32   D  0.131503  965.0           0.102145  0.131815  0.141040
# 1       53   D  0.131503  966.0           0.307377  0.131547  0.140947
# 2       74   D  0.131279  960.0           0.205339  0.131302  0.140835
# 3       62   D  0.130610  960.0           0.205761  0.131190  0.140625
# 4       49   D  0.130163  955.0           0.206186  0.131101  0.140397
#
#       Lag_1     Lag_2     Lag_3     Lag_4     Lag_5  Volatility
# 0  0.131503  0.131726  0.131726  0.131503  0.131279    0.000971
# 1  0.131503  0.131503  0.131726  0.131726  0.131503    0.000621
# 2  0.131279  0.131503  0.131503  0.131726  0.131726    0.000400
# 3  0.130610  0.131279  0.131503  0.131503  0.131726    0.000539
# 4  0.130163  0.130610  0.131279  0.131503  0.131503    0.000697

# %% [markdown]
# Now the data is in ascending order according to the dates. We can go forward with model selection and training.

# %% [markdown]
# ### Model Selection

# %%
stock_data = df

# %%
# Perform the Augmented Dickey-Fuller test to check stationarity on the 'Closing Price'
from statsmodels.tsa.stattools import adfuller

# ADF test on 'Closing Price'
adf_result = adfuller(stock_data['close'])

# Extract the results
adf_statistic = adf_result[0]
p_value = adf_result[1]
critical_values = adf_result[4]

adf_statistic, p_value, critical_values
# Out:
# (-2.426368046530239,
#  0.13443209114638316,
#  {'1%': -3.432135995428144,
#   '5%': -2.8623291535344446,
#   '10%': -2.5671900782337533})

# %% [markdown]
# ### ADF Test Results
#
# #### ADF Statistic
# - **Value**: -3.63
#
# #### p-value
# - **Value**: 0.0052
#
# #### Critical Values
# - **1%**: -3.43
# - **5%**: -2.86
# - **10%**: -2.57
#
# ### Interpretation
# Since the ADF Statistic (-3.63) is lower than the critical values at all levels (1%, 5%, and 10%), and the p-value (0.0052) is less than 0.05, we can reject the null hypothesis of the ADF test.
#
# ### Conclusion
# The data is stationary, which is a good sign for proceeding with an ARIMA model.

# %%
df
# Out:
#            date   first      high       low     close         value       vol  \
# 0    2009-08-19   963.0  0.191389  0.207991  0.131503  3.055110e+08  0.000110
# 1    2009-08-22   970.0  0.189824  0.207775  0.131279  4.754206e+08  0.000172
# 2    2009-08-23   970.0  0.189824  0.205616  0.130610  1.180368e+09  0.000430
# 3    2009-08-24   964.0  0.189041  0.206048  0.130163  9.687572e+08  0.000353
# 4    2009-08-25   960.0  0.188063  0.206263  0.129716  7.652826e+08  0.000279
# ...         ...     ...       ...       ...       ...           ...       ...
# 3682 2024-11-20  1746.0  0.349902  0.377106  0.303193  4.129098e+11  0.082590
# 3683 2024-11-23  1770.0  0.352446  0.377754  0.314133  5.691964e+11  0.110789
# 3684 2024-11-24  1829.0  0.362231  0.392009  0.325742  4.475030e+11  0.084636
# 3685 2024-11-25  1905.0  0.372798  0.404536  0.338022  5.028978e+11  0.092367
# 3686 2024-11-26  1962.0  0.383953  0.399568  0.343603  1.319969e+12  0.239341
#
#       openint per      open    last  percentage_change      MA10      MA50  \
# 0          32   D  0.131503   965.0           0.102145  0.131815  0.141040
# 1          53   D  0.131503   966.0           0.307377  0.131547  0.140947
# 2          74   D  0.131279   960.0           0.205339  0.131302  0.140835
# 3          62   D  0.130610   960.0           0.205761  0.131190  0.140625
# 4          49   D  0.130163   955.0           0.206186  0.131101  0.140397
# ...       ...  ..       ...     ...                ...       ...       ...
# 3682     2826   D  0.314579  1746.0          -2.725250  0.287453  0.281692
# 3683     3671   D  0.303193  1801.0          -2.810811  0.292990  0.282559
# 3684     2161   D  0.314133  1851.0          -2.887139  0.298660  0.283813
# 3685     2426   D  0.325742  1905.0          -1.295337  0.304577  0.285416
# 3686     7853   D  0.338022  1865.0           0.000000  0.311186  0.287136
#
#          Lag_1     Lag_2     Lag_3     Lag_4     Lag_5  Volatility
# 0     0.131503  0.131726  0.131726  0.131503  0.131279    0.000971
# 1     0.131503  0.131503  0.131726  0.131726  0.131503    0.000621
# 2     0.131279  0.131503  0.131503  0.131726  0.131726    0.000400
# 3     0.130610  0.131279  0.131503  0.131503  0.131726    0.000539
# 4     0.130163  0.130610  0.131279  0.131503  0.131503    0.000697
# ...        ...       ...       ...       ...       ...         ...
# 3682  0.314579  0.305649  0.294262  0.291806  0.280866    0.017507
# 3683  0.303193  0.314579  0.305649  0.294262  0.291806    0.016126
# 3684  0.314133  0.303193  0.314579  0.305649  0.294262    0.016726
# 3685  0.325742  0.314133  0.303193  0.314579  0.305649    0.019221
# 3686  0.338022  0.325742  0.314133  0.303193  0.314579    0.020218
#
# [3687 rows x 20 columns]

# %%
from statsmodels.tsa.stattools import adfuller

stock_data = df
result = adfuller(stock_data['close'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ADF Statistic: -2.426368046530239
# p-value: 0.13443209114638316

# %%
from statsmodels.tsa.arima.model import ARIMA
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# اطمینان از فرمت datetime ستون date
# stock_data['date'] = pd.to_datetime(stock_data['date'], format='%Y%m%d')
# stock_data = stock_data.sort_values('date')

# Split data into training (2009-2021) and testing (2022-2024) sets
train_data = df[(df['date'] >= '2009-01-01') & (df['date'] <= '2021-12-31')]['close']
test_data = df[(df['date'] >= '2022-01-01') & (df['date'] <= '2024-12-31')]['close']

dates_test = df[(df['date'] >= '2022-01-01') & (df['date'] <= '2024-12-31')]['date']

# Fit ARIMA model (initial parameters for p, d, q can be refined later)
model_arima = ARIMA(train_data, order=(5, 1, 0))  # ARIMA(5,1,0)
arima_fit = model_arima.fit()

# Make predictions
arima_predictions = arima_fit.forecast(steps=len(test_data))

# Calculate evaluation metrics
mse_arima = mean_squared_error(test_data, arima_predictions)
mae_arima = mean_absolute_error(test_data, arima_predictions)
rsq_arima = 1 - (sum((test_data - arima_predictions)**2) / sum((test_data - np.mean(test_data))**2))

# Plot the entire dataset along with test predictions
plt.figure(figsize=(15, 7))

# Plot all data (gray)
plt.plot(df['date'], df['close'], label='All Data', color='gray', alpha=0.5)

# Plot training data (blue)
plt.plot(df[(df['date'] >= '2009-01-01') & (df['date'] <= '2021-12-31')]['date'],
                    train_data, label='Training Data', color='blue')

# Plot actual test data (red)
plt.plot(dates_test, test_data, label='Actual (Test)', color='red')

# Plot ARIMA predictions on the test data (yellow)
plt.plot(dates_test, arima_predictions, label='Predicted (ARIMA)', color='yellow')

# Format the x-axis for better readability
plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Display major ticks every year
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))  # More detailed format: Year-Month-Day

# Rotate and align the tick labels for better readability
plt.gcf().autofmt_xdate()

plt.title('ARIMA Model - Closing Price Prediction')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.tight_layout()
plt.show()

# Print evaluation metrics
print(f'MSE: {mse_arima:.3f}, MAE: {mae_arima:.3f}, R-Squared: {rsq_arima:.3f}')
print(train_data.head())
print(test_data.head())
print("Test Dates:", dates_test)
# Out:
# MSE: 0.006, MAE: 0.064, R-Squared: -0.128
# 0    0.131503
# 1    0.131279
# 2    0.130610
# 3    0.130163
# 4    0.129716
# Name: close, dtype: float64
# 2993    0.337799
# 2994    0.336906
# 2995    0.334226
# 2996    0.325966
# 2997    0.327975
# Name: close, dtype: float64
# Test Dates: 2993   2022-01-01
# 2994   2022-01-02
# 2995   2022-01-03
# 2996   2022-01-04
# 2997   2022-01-05
#           ...
# 3682   2024-11-20
# 3683   2024-11-23
# 3684   2024-11-24
# 3685   2024-11-25
# 3686   2024-11-26
# Name: date, Length: 694, dtype: datetime64[ns]

# %% [markdown]
# Simple ARIMA doesn't give correct output as we only predict using single variable closing price.
#
# Now when we try using other features including Volume, Moving Average and Volatility, it gives us better predictions.

# %%
from statsmodels.tsa.arima.model import ARIMA
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
import pandas as pd

# اطمینان از فرمت datetime ستون date
# df['date'] = pd.to_datetime(df['date'], errors='coerce')
# df = df.dropna(subset=['date'])
# df = df.sort_values('date')

# Split data into training (2009-2021) and testing (2022-2024) sets
train_data = df[(df['date'] >= '2009-01-01') & (df['date'] <= '2021-12-31')]['close']
test_data = df[(df['date'] >= '2022-01-01') & (df['date'] <= '2024-12-31')]['close']

# استخراج تاریخ‌های مربوط به داده‌های تست
dates_test = df[(df['date'] >= '2022-01-01') & (df['date'] <= '2024-12-31')]['date']

# Define exogenous variables (for example: Volume, MA10, Volatility)
exog_train = df[(df['date'] >= '2009-01-01') & (df['date'] <= '2021-12-31')][['vol', 'MA10', 'Volatility']]
exog_test = df[(df['date'] >= '2022-01-01') & (df['date'] <= '2024-12-31')][['vol', 'MA10', 'Volatility']]

# Fit ARIMAX model
model_arimax = ARIMA(train_data, exog=exog_train, order=(5, 0, 0))
arimax_fit = model_arimax.fit()

# Make predictions using exogenous variables for the test set
arimax_predictions = arimax_fit.forecast(steps=len(test_data), exog=exog_test)

# Evaluate performance
mse_arimax = mean_squared_error(test_data, arimax_predictions)
mae_arimax = mean_absolute_error(test_data, arimax_predictions)
rsq_arimax = 1 - (sum((test_data - arimax_predictions)**2) / sum((test_data - np.mean(test_data))**2))

print(f'MSE: {mse_arimax:.3f}, MAE: {mae_arimax:.3f}, R-Squared: {rsq_arimax:.3f}')

# Plot the results
plt.figure(figsize=(15, 7))

# Plot all data
plt.plot(df['date'], df['close'], label='All Data', color='gray', alpha=0.5)

# Plot training data
plt.plot(df[(df['date'] >= '2009-01-01') & (df['date'] <= '2021-12-31')]['date'],
           train_data, label='Training Data', color='blue')

# Plot actual test data
plt.plot(dates_test, test_data, label='Actual (Test)', color='red')

# Plot ARIMAX predictions on the test data
plt.plot(dates_test, arimax_predictions, label='Predicted (ARIMAX)', color='yellow')

# Set x-axis limits
plt.xlim(pd.to_datetime('2009-01-01'), pd.to_datetime('2025-01-01'))

plt.title('ARIMAX Model - Closing Price Prediction')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

print(train_data.head())
print(test_data.head())
print("Test Dates:", dates_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# MSE: 0.001, MAE: 0.020, R-Squared: 0.902
# 0    0.131503
# 1    0.131279
# 2    0.130610
# 3    0.130163
# 4    0.129716
# Name: close, dtype: float64
# 2993    0.337799
# 2994    0.336906
# 2995    0.334226
# 2996    0.325966
# 2997    0.327975
# Name: close, dtype: float64
# Test Dates: 2993   2022-01-01
# 2994   2022-01-02
# 2995   2022-01-03
# 2996   2022-01-04
# 2997   2022-01-05
#           ...
# 3682   2024-11-20
# 3683   2024-11-23
# 3684   2024-11-24
# 3685   2024-11-25
# 3686   2024-11-26
# Name: date, Length: 694, dtype: datetime64[ns]

# %% [markdown]
# We can see that ARIMA with other features gave us good results. But We can't take Volume and Variability features, as they won't be available to us during predictions.
#
# Hence we try to do predictions using Lag.

# %%
from statsmodels.tsa.arima.model import ARIMA
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
import pandas as pd

# اطمینان از فرمت datetime ستون date
# stock_data['date'] = pd.to_datetime(stock_data['date'], errors='coerce')  # تبدیل date به datetime
# stock_data = stock_data.dropna(subset=['date'])  # حذف مقادیر نامعتبر در ستون date

# # مرتب‌سازی بر اساس تاریخ
# stock_data = stock_data.sort_values('date')

# Split data into training (2009-2021) and testing (2022-2024) sets
# train_data = stock_data[(stock_data['date'] >= '2009-01-01') & (stock_data['date'] <= '2021-12-31')]['close']
# test_data = stock_data[(stock_data['date'] >= '2022-01-01') & (stock_data['date'] <= '2024-12-31')]['close']

# # استخراج تاریخ‌های مربوط به داده‌های تست
# dates_test = stock_data[(stock_data['date'] >= '2022-01-01') & (stock_data['date'] <= '2024-12-31')]['date']

# Use lag features (e.g., Lag_1, Lag_2, ..., Lag_5) instead of moving averages and volatility
exog_train = df[(df['date'] >= '2009-01-01') & (df['date'] <= '2021-12-31')][['Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5']]
exog_test = df[(df['date'] >= '2022-01-01') & (df['date'] <= '2024-12-31')][['Lag_1', 'Lag_2', 'Lag_3', 'Lag_4', 'Lag_5']]

# Fit ARIMAX model with lagged features as exogenous variables
model_arimax = ARIMA(train_data, exog=exog_train, order=(5, 0, 0))  # تنظیم مقادیر p, d, q
arimax_fit = model_arimax.fit()

# Make predictions using exogenous variables for the test set
arimax_predictions = arimax_fit.forecast(steps=len(test_data), exog=exog_test)

# Evaluate performance
mse_arimax = mean_squared_error(test_data, arimax_predictions)
mae_arimax = mean_absolute_error(test_data, arimax_predictions)
rsq_arimax = 1 - (sum((test_data - arimax_predictions)**2) / sum((test_data - np.mean(test_data))**2))

print(f'MSE(ARIMAX): {mse_arimax:.4f}, MAE(ARIMAX): {mae_arimax:.4f}, R-Squared(ARIMAX): {rsq_arimax:.4f}')

# Plot the results
plt.figure(figsize=(15, 7))

# نمایش کل داده‌ها به رنگ خاکستری
plt.plot(df['date'], df['close'], label='All Data', color='gray', alpha=0.5)

# نمایش داده‌های ترین به رنگ آبی
plt.plot(df[(df['date'] >= '2009-01-01') & (df['date'] <= '2021-12-31')]['date'],
         train_data, label='Train Data', color='blue')

# نمایش داده‌های تست به رنگ قرمز
plt.plot(dates_test, test_data, label='Test Data', color='red')

# نمایش داده‌های پیش‌بینی‌شده به رنگ زرد
plt.plot(dates_test, arimax_predictions, label='Predicted (ARIMAX)', color='yellow')

plt.title('ARIMAX Model - Closing Price Prediction')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# MSE(ARIMAX): 0.0001, MAE(ARIMAX): 0.0068, R-Squared(ARIMAX): 0.9839

# %% [markdown]
# ### LSTM

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Prepare the data for LSTM
def create_dataset(data, time_step=90):
    X, Y = [], []
    for i in range(time_step, len(data)):
        X.append(data[i-time_step:i, 0])
        Y.append(data[i, 0])
    return np.array(X), np.array(Y)

# Ensure the 'date' column is in datetime format
# stock_data['date'] = pd.to_datetime(stock_data['date'], errors='coerce')
# stock_data = stock_data.dropna(subset=['date'])  # حذف مقادیر نامعتبر
# stock_data = stock_data.sort_values('date')  # مرتب‌سازی بر اساس تاریخ

# Split data into training (2009-2021) and testing (2022-2024) sets
# train_data = stock_data[(stock_data['date'] >= '2009-01-01') & (stock_data['date'] <= '2021-12-31')]['close']
# test_data = stock_data[(stock_data['date'] >= '2022-01-01') & (stock_data['date'] <= '2024-12-31')]['close']

# dates_test = stock_data[(stock_data['date'] >= '2022-01-01') & (stock_data['date'] <= '2024-12-31')]['date']

# Scaling the 'Closing Price' column between 0 and 1 for LSTM
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_train_data = scaler.fit_transform(train_data.values.reshape(-1, 1))
scaled_test_data = scaler.transform(test_data.values.reshape(-1, 1))

# Create the LSTM input dataset
time_step = 35
X_train, Y_train = create_dataset(scaled_train_data, time_step)
X_test, Y_test = create_dataset(scaled_test_data, time_step)

# Reshaping input to be [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Build LSTM model
model_lstm = Sequential()
model_lstm.add(LSTM(units=100, return_sequences=True, input_shape=(time_step, 1)))
model_lstm.add(Dropout(0.1))  # کاهش Dropout
model_lstm.add(LSTM(units=100))
model_lstm.add(Dropout(0.1))
model_lstm.add(Dense(64, activation='relu'))
model_lstm.add(Dense(1))

# Compile the LSTM model with custom optimizer
optimizer = Adam(learning_rate=0.001)  # افزایش نرخ یادگیری
model_lstm.compile(loss='mean_squared_error', optimizer=optimizer)

# Early Stopping to avoid overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)  # افزایش patience

# Train the LSTM model
history = model_lstm.fit(
    X_train, Y_train,
    epochs=200, batch_size=32,
    validation_split=0.1,
    callbacks=[early_stop],
    verbose=1
)

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Predict on test data
lstm_predictions = model_lstm.predict(X_test)
lstm_predictions = scaler.inverse_transform(lstm_predictions)

# Inverse scaling for actual test values
Y_test_scaled = scaler.inverse_transform(Y_test.reshape(-1, 1))

# Calculate evaluation metrics for LSTM
mse_lstm = mean_squared_error(Y_test_scaled, lstm_predictions)
mae_lstm = mean_absolute_error(Y_test_scaled, lstm_predictions)

ss_res = np.sum((Y_test_scaled - lstm_predictions) ** 2)
ss_tot = np.sum((Y_test_scaled - np.mean(Y_test_scaled)) ** 2)
rsq_lstm = 1 - (ss_res / ss_tot)

# Plot the LSTM results
plt.figure(figsize=(12, 6))

# رسم کل داده‌ها با رنگ خاکستری
plt.plot(stock_data['date'], stock_data['close'], color='gray', alpha=0.5, label='All Data')

# رسم داده‌های آموزشی با رنگ آبی
plt.plot(train_data.index, train_data, color='blue', label='Training Data')

# رسم داده‌های تست با رنگ قرمز
plt.plot(test_data.index, test_data, color='red', label='Testing Data')

# رسم داده‌های پیش‌بینی شده با رنگ زرد
plt.plot(dates_test[time_step:], lstm_predictions, color='yellow', label='Predicted (LSTM)')

plt.title('LSTM Model - Closing Price Prediction')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


# Print evaluation metrics
print(f"MSE (LSTM): {mse_lstm:.5f}")
print(f"MAE (LSTM): {mae_lstm:.5f}")
print(f"R-Squared (LSTM): {rsq_lstm:.5f}")
print(train_data.head())
print(test_data.head())
print("Test Dates:", dates_test)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0076 - val_loss: 0.0028
# Epoch 2/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 8.2529e-04 - val_loss: 0.0023
# Epoch 3/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.4963e-04 - val_loss: 0.0020
# Epoch 4/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.2851e-04 - val_loss: 0.0018
# Epoch 5/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.6607e-04 - val_loss: 0.0014
# Epoch 6/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.1408e-04 - val_loss: 0.0014
# Epoch 7/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.0049e-04 - val_loss: 0.0024
# Epoch 8/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.5939e-04 - val_loss: 0.0011
# Epoch 9/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.0730e-04 - val_loss: 9.9713e-04
# Epoch 10/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4836e-04 - val_loss: 9.0500e-04
# Epoch 11/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.9646e-04 - val_loss: 0.0020
# Epoch 12/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1470e-04 - val_loss: 0.0011
# Epoch 13/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.3096e-04 - val_loss: 8.3128e-04
# Epoch 14/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1592e-04 - val_loss: 0.0026
# Epoch 15/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.3175e-04 - val_loss: 8.4045e-04
# Epoch 16/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.2206e-04 - val_loss: 7.5602e-04
# Epoch 17/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1989e-04 - val_loss: 9.3219e-04
# Epoch 18/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 2.6926e-04 - val_loss: 6.7612e-04
# Epoch 19/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.7839e-04 - val_loss: 5.7492e-04
# Epoch 20/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.6147e-04 - val_loss: 0.0011
# Epoch 21/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3799e-04 - val_loss: 9.8979e-04
# Epoch 22/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4535e-04 - val_loss: 7.6438e-04
# Epoch 23/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4067e-04 - val_loss: 5.4651e-04
# Epoch 24/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0270e-04 - val_loss: 5.1423e-04
# Epoch 25/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.0963e-04 - val_loss: 4.9335e-04
# Epoch 26/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9088e-04 - val_loss: 5.1092e-04
# Epoch 27/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.5513e-04 - val_loss: 4.3135e-04
# Epoch 28/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3877e-04 - val_loss: 5.3284e-04
# Epoch 29/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.5325e-04 - val_loss: 5.9083e-04
# Epoch 30/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 1.9517e-04 - val_loss: 3.8712e-04
# Epoch 31/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.2100e-04 - val_loss: 3.6645e-04
# Epoch 32/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0259e-04 - val_loss: 4.5167e-04
# Epoch 33/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8778e-04 - val_loss: 4.0082e-04
# Epoch 34/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2902e-04 - val_loss: 0.0012
# Epoch 35/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2036e-04 - val_loss: 3.5231e-04
# Epoch 36/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3432e-04 - val_loss: 3.6603e-04
# Epoch 37/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.5557e-04 - val_loss: 5.0697e-04
# Epoch 38/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9771e-04 - val_loss: 3.2516e-04
# Epoch 39/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4833e-04 - val_loss: 3.2178e-04
# Epoch 40/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4400e-04 - val_loss: 4.0118e-04
# Epoch 41/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.8203e-04 - val_loss: 3.0974e-04
# Epoch 42/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.7457e-04 - val_loss: 8.2278e-04
# Epoch 43/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4986e-04 - val_loss: 5.8428e-04
# Epoch 44/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.7497e-04 - val_loss: 4.9930e-04
# Epoch 45/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.5616e-04 - val_loss: 5.4023e-04
# Epoch 46/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2480e-04 - val_loss: 8.7803e-04
# Epoch 47/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8506e-04 - val_loss: 5.0030e-04
# Epoch 48/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3602e-04 - val_loss: 3.4200e-04
# Epoch 49/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6913e-04 - val_loss: 3.0537e-04
# Epoch 50/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6203e-04 - val_loss: 7.3409e-04
# Epoch 51/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5841e-04 - val_loss: 0.0013
# Epoch 52/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.6690e-04 - val_loss: 5.0868e-04
# Epoch 53/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7354e-04 - val_loss: 3.1521e-04
# Epoch 54/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.4078e-04 - val_loss: 2.7720e-04
# Epoch 55/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.6618e-04 - val_loss: 3.5259e-04
# Epoch 56/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0872e-04 - val_loss: 8.1118e-04
# Epoch 57/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.9364e-04 - val_loss: 3.5207e-04
# Epoch 58/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6744e-04 - val_loss: 4.3758e-04
# Epoch 59/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0272e-04 - val_loss: 0.0011
# Epoch 60/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.6089e-04 - val_loss: 2.8176e-04
# Epoch 61/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9026e-04 - val_loss: 6.9569e-04
# Epoch 62/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.4278e-04 - val_loss: 3.4410e-04
# Epoch 63/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6483e-04 - val_loss: 0.0015
# Epoch 64/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 2.8449e-04 - val_loss: 2.9764e-04
# Epoch 65/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.5045e-04 - val_loss: 4.5126e-04
# Epoch 66/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.4064e-04 - val_loss: 4.3131e-04
# Epoch 67/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6169e-04 - val_loss: 5.1906e-04
# Epoch 68/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5232e-04 - val_loss: 4.5404e-04
# Epoch 69/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8360e-04 - val_loss: 6.7682e-04
# Epoch 70/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2313e-04 - val_loss: 5.3084e-04
# Epoch 71/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4518e-04 - val_loss: 0.0015
# Epoch 72/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4661e-04 - val_loss: 5.3741e-04
# Epoch 73/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9656e-04 - val_loss: 5.7489e-04
# Epoch 74/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 2.1502e-04 - val_loss: 2.6316e-04
# Epoch 75/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.4801e-04 - val_loss: 3.1630e-04
# Epoch 76/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5297e-04 - val_loss: 4.3151e-04
# Epoch 77/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3348e-04 - val_loss: 5.1020e-04
# Epoch 78/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8857e-04 - val_loss: 9.3881e-04
# Epoch 79/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8841e-04 - val_loss: 3.1185e-04
# Epoch 80/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7054e-04 - val_loss: 6.4544e-04
# Epoch 81/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.0026e-04 - val_loss: 8.6443e-04
# Epoch 82/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1859e-04 - val_loss: 3.7100e-04
# Epoch 83/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2248e-04 - val_loss: 4.4014e-04
# Epoch 84/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6414e-04 - val_loss: 6.0310e-04
# Epoch 85/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6954e-04 - val_loss: 2.6935e-04
# Epoch 86/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1351e-04 - val_loss: 9.5018e-04
# Epoch 87/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 2.0489e-04 - val_loss: 3.9005e-04
# Epoch 88/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.2817e-04 - val_loss: 2.8267e-04
# Epoch 89/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.2807e-04 - val_loss: 6.2685e-04
# Epoch 90/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5208e-04 - val_loss: 3.3041e-04
# Epoch 91/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4668e-04 - val_loss: 6.9692e-04
# Epoch 92/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6572e-04 - val_loss: 5.9074e-04
# Epoch 93/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1067e-04 - val_loss: 8.5844e-04
# Epoch 94/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2692e-04 - val_loss: 2.8762e-04
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# MSE (LSTM): 0.00009
# MAE (LSTM): 0.00680
# R-Squared (LSTM): 0.98464
# 0    0.131503
# 1    0.131279
# 2    0.130610
# 3    0.130163
# 4    0.129716
# Name: close, dtype: float64
# 2993    0.337799
# 2994    0.336906
# 2995    0.334226
# 2996    0.325966
# 2997    0.327975
# Name: close, dtype: float64
# Test Dates: 2993   2022-01-01
# 2994   2022-01-02
# 2995   2022-01-03
# 2996   2022-01-04
# 2997   2022-01-05
#           ...
# 3682   2024-11-20
# 3683   2024-11-23
# 3684   2024-11-24
# 3685   2024-11-25
# 3686   2024-11-26
# Name: date, Length: 694, dtype: datetime64[ns]

# %% [markdown]
# ### GRU

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Prepare the data for GRU
def create_dataset(data, time_step=90):
    X, Y = [], []
    for i in range(time_step, len(data)):
        X.append(data[i-time_step:i, 0])
        Y.append(data[i, 0])
    return np.array(X), np.array(Y)

# Ensure the 'date' column is in datetime format
# stock_data['date'] = pd.to_datetime(stock_data['date'], errors='coerce')
# stock_data = stock_data.dropna(subset=['date'])  # حذف مقادیر نامعتبر
# stock_data = stock_data.sort_values('date')  # مرتب‌سازی بر اساس تاریخ

# Split data into training (2009-2021) and testing (2022-2024) sets
# train_data = stock_data[(stock_data['date'] >= '2009-01-01') & (stock_data['date'] <= '2021-12-31')]['close']
# test_data = stock_data[(stock_data['date'] >= '2022-01-01') & (stock_data['date'] <= '2024-12-31')]['close']

# dates_test = stock_data[(stock_data['date'] >= '2022-01-01') & (stock_data['date'] <= '2024-12-31')]['date']

# Scaling the 'Closing Price' column between 0 and 1 for GRU
# scaler = MinMaxScaler(feature_range=(0, 1))
# scaled_train_data = scaler.fit_transform(train_data.values.reshape(-1, 1))
# scaled_test_data = scaler.transform(test_data.values.reshape(-1, 1))

# Create the GRU input dataset
# time_step = 90  # وابستگی طولانی‌تر
# X_train, Y_train = create_dataset(scaled_train_data, time_step)
# X_test, Y_test = create_dataset(scaled_test_data, time_step)

# Reshaping input to be [samples, time steps, features]
# X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
# X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Build Enhanced GRU model
model_gru = Sequential()
model_gru.add(GRU(units=128, return_sequences=True, input_shape=(time_step, 1)))
model_gru.add(Dropout(0.2))
model_gru.add(GRU(units=64, return_sequences=True))
model_gru.add(Dropout(0.2))
model_gru.add(GRU(units=32))
model_gru.add(Dropout(0.1))
model_gru.add(Dense(1))

# Compile the GRU model with a lower learning rate
optimizer = Adam(learning_rate=0.0005)  # کاهش نرخ یادگیری به مقدار مناسب
model_gru.compile(loss='mean_squared_error', optimizer=optimizer)

# Early Stopping to avoid overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Train the GRU model
history = model_gru.fit(X_train, Y_train,
                        epochs=200,  # تنظیم تعداد ایپاک‌ها
                        batch_size=32,  # تنظیم سایز بچ
                        validation_split=0.1,
                        callbacks=[early_stop],
                        verbose=1)

# Predict on test data
gru_predictions = model_gru.predict(X_test)
gru_predictions = scaler.inverse_transform(gru_predictions)

# Inverse scaling for actual test values
Y_test_scaled = scaler.inverse_transform(Y_test.reshape(-1, 1))

# Calculate evaluation metrics for GRU
mse_gru = mean_squared_error(Y_test_scaled, gru_predictions)
mae_gru = mean_absolute_error(Y_test_scaled, gru_predictions)

# Calculate R-Squared
ss_res = np.sum((Y_test_scaled - gru_predictions) ** 2)
ss_tot = np.sum((Y_test_scaled - np.mean(Y_test_scaled)) ** 2)
rsq_gru = 1 - (ss_res / ss_tot)

# Plot the GRU results
plt.figure(figsize=(12, 6))

# رسم کل داده‌ها با رنگ خاکستری
plt.plot(stock_data['date'], stock_data['close'], color='gray', alpha=0.5, label='All Data')

# رسم داده‌های آموزشی با رنگ آبی
plt.plot(train_data.index, train_data, color='blue', label='Training Data')

# رسم داده‌های تست با رنگ قرمز
plt.plot(test_data.index, test_data, color='red', label='Testing Data')

# رسم داده‌های پیش‌بینی شده با رنگ زرد
plt.plot(dates_test[time_step:], gru_predictions, color='yellow', label='Predicted (GRU)')

plt.title('GRU Model - Closing Price Prediction')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Print evaluation metrics
print(f"MSE (GRU): {mse_gru:.7f}")
print(f"MAE (GRU): {mae_gru:.7f}")
print(f"R-Squared (GRU): {rsq_gru:.5f}")
print(train_data.head())
print(test_data.head())
print("Test Dates:", dates_test)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0097 - val_loss: 0.0018
# Epoch 2/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 8.4027e-04 - val_loss: 0.0023
# Epoch 3/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.1957e-04 - val_loss: 0.0015
# Epoch 4/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.9515e-04 - val_loss: 0.0012
# Epoch 5/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.6945e-04 - val_loss: 0.0013
# Epoch 6/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.5597e-04 - val_loss: 0.0012
# Epoch 7/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.3156e-04 - val_loss: 0.0010
# Epoch 8/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.2156e-04 - val_loss: 9.6026e-04
# Epoch 9/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.2583e-04 - val_loss: 9.9546e-04
# Epoch 10/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 5.3891e-04 - val_loss: 9.4457e-04
# Epoch 11/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.3917e-04 - val_loss: 9.4890e-04
# Epoch 12/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.7696e-04 - val_loss: 0.0014
# Epoch 13/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.8028e-04 - val_loss: 0.0014
# Epoch 14/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.2052e-04 - val_loss: 9.5059e-04
# Epoch 15/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.1042e-04 - val_loss: 8.3028e-04
# Epoch 16/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.5785e-04 - val_loss: 0.0010
# Epoch 17/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4335e-04 - val_loss: 0.0017
# Epoch 18/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.8600e-04 - val_loss: 6.1022e-04
# Epoch 19/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.4475e-04 - val_loss: 7.4070e-04
# Epoch 20/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.7732e-04 - val_loss: 5.5566e-04
# Epoch 21/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.5968e-04 - val_loss: 5.5274e-04
# Epoch 22/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.9158e-04 - val_loss: 5.0304e-04
# Epoch 23/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.3300e-04 - val_loss: 0.0015
# Epoch 24/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.8680e-04 - val_loss: 4.6547e-04
# Epoch 25/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.5348e-04 - val_loss: 5.1194e-04
# Epoch 26/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.2675e-04 - val_loss: 4.3930e-04
# Epoch 27/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4122e-04 - val_loss: 6.9380e-04
# Epoch 28/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.8089e-04 - val_loss: 4.7877e-04
# Epoch 29/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.0503e-04 - val_loss: 0.0015
# Epoch 30/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.1308e-04 - val_loss: 5.1853e-04
# Epoch 31/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2542e-04 - val_loss: 9.2656e-04
# Epoch 32/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.3801e-04 - val_loss: 0.0028
# Epoch 33/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 3.3878e-04 - val_loss: 4.3450e-04
# Epoch 34/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 3.4824e-04 - val_loss: 4.0498e-04
# Epoch 35/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.3828e-04 - val_loss: 4.8827e-04
# Epoch 36/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.5339e-04 - val_loss: 4.8459e-04
# Epoch 37/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 2.7713e-04 - val_loss: 4.2802e-04
# Epoch 38/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7510e-04 - val_loss: 3.7837e-04
# Epoch 39/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.2194e-04 - val_loss: 0.0021
# Epoch 40/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.1071e-04 - val_loss: 8.5439e-04
# Epoch 41/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7747e-04 - val_loss: 0.0014
# Epoch 42/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7099e-04 - val_loss: 4.0560e-04
# Epoch 43/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 2.7266e-04 - val_loss: 4.9038e-04
# Epoch 44/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 3.7382e-04 - val_loss: 8.1932e-04
# Epoch 45/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.6484e-04 - val_loss: 3.2338e-04
# Epoch 46/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.6799e-04 - val_loss: 3.2536e-04
# Epoch 47/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.2308e-04 - val_loss: 4.7177e-04
# Epoch 48/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7719e-04 - val_loss: 3.5793e-04
# Epoch 49/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.7510e-04 - val_loss: 2.9739e-04
# Epoch 50/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.1609e-04 - val_loss: 3.4529e-04
# Epoch 51/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.2635e-04 - val_loss: 4.3276e-04
# Epoch 52/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.6588e-04 - val_loss: 3.7704e-04
# Epoch 53/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 3.7022e-04 - val_loss: 7.6108e-04
# Epoch 54/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.8898e-04 - val_loss: 3.5286e-04
# Epoch 55/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.4459e-04 - val_loss: 5.5213e-04
# Epoch 56/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.8201e-04 - val_loss: 3.1320e-04
# Epoch 57/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 2.1740e-04 - val_loss: 3.2545e-04
# Epoch 58/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.0051e-04 - val_loss: 4.3753e-04
# Epoch 59/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3594e-04 - val_loss: 6.6619e-04
# Epoch 60/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5368e-04 - val_loss: 3.1115e-04
# Epoch 61/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2384e-04 - val_loss: 4.2487e-04
# Epoch 62/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9931e-04 - val_loss: 8.1043e-04
# Epoch 63/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 3.1720e-04 - val_loss: 7.3163e-04
# Epoch 64/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.7670e-04 - val_loss: 3.3758e-04
# Epoch 65/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 2.8396e-04 - val_loss: 2.9573e-04
# Epoch 66/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.7135e-04 - val_loss: 7.0349e-04
# Epoch 67/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5796e-04 - val_loss: 5.7696e-04
# Epoch 68/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5936e-04 - val_loss: 9.2908e-04
# Epoch 69/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.7577e-04 - val_loss: 3.1264e-04
# Epoch 70/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.4214e-04 - val_loss: 3.5656e-04
# Epoch 71/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3453e-04 - val_loss: 3.0664e-04
# Epoch 72/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2867e-04 - val_loss: 5.0353e-04
# Epoch 73/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.1259e-04 - val_loss: 3.9517e-04
# Epoch 74/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.1053e-04 - val_loss: 4.6056e-04
# Epoch 75/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6891e-04 - val_loss: 0.0014
# Epoch 76/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.1573e-04 - val_loss: 3.4441e-04
# Epoch 77/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.4268e-04 - val_loss: 0.0011
# Epoch 78/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4138e-04 - val_loss: 3.5467e-04
# Epoch 79/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.9801e-04 - val_loss: 3.2142e-04
# Epoch 80/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.1946e-04 - val_loss: 3.0598e-04
# Epoch 81/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.5465e-04 - val_loss: 5.3346e-04
# Epoch 82/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.9537e-04 - val_loss: 3.1905e-04
# Epoch 83/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.2045e-04 - val_loss: 4.5021e-04
# Epoch 84/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4681e-04 - val_loss: 3.2246e-04
# Epoch 85/200
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1492e-04 - val_loss: 3.1604e-04
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# MSE (Enhanced GRU): 0.0000959
# MAE (Enhanced GRU): 0.0068036
# R-Squared (Enhanced GRU): 0.98408
# 0    0.131503
# 1    0.131279
# 2    0.130610
# 3    0.130163
# 4    0.129716
# Name: close, dtype: float64
# 2993    0.337799
# 2994    0.336906
# 2995    0.334226
# 2996    0.325966
# 2997    0.327975
# Name: close, dtype: float64
# Test Dates: 2993   2022-01-01
# 2994   2022-01-02
# 2995   2022-01-03
# 2996   2022-01-04
# 2997   2022-01-05
#           ...
# 3682   2024-11-20
# 3683   2024-11-23
# 3684   2024-11-24
# 3685   2024-11-25
# 3686   2024-11-26
# Name: date, Length: 694, dtype: datetime64[ns]

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# تنظیم داده‌ها برای مدل ARIMAX
# train_data_arimax = stock_data[(stock_data['date'] >= '2009-01-01') & (stock_data['date'] <= '2021-12-31')]['close']
# test_data_arimax = stock_data[(stock_data['date'] >= '2022-01-01') & (stock_data['date'] <= '2024-12-31')]['close']

# تنظیم مدل ARIMAX
arimax_model = SARIMAX(train_data, order=(5, 1, 0), seasonal_order=(1, 1, 1, 12))
arimax_result = arimax_model.fit(disp=False)

# پیش‌بینی یک ماه آینده
future_steps = 30  # 30 روز آینده
arimax_forecast = arimax_result.get_forecast(steps=future_steps).predicted_mean

# رسم پیش‌بینی ARIMAX
plt.figure(figsize=(10, 6))
plt.plot(test_data.index[-future_steps:], test_data[-future_steps:], label='Actual', color='blue')
plt.plot(test_data.index[-future_steps:], arimax_forecast, label='Predicted (ARIMAX)', color='red')
plt.title('ARIMAX Model - 1-Month Ahead Prediction')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# تنظیم ورودی برای پیش‌بینی آینده
future_steps = 30
input_seq = scaled_test_data[-90:]  # آخرین 90 داده برای شروع پیش‌بینی
future_predictions = []

# پیش‌بینی داده‌های آینده
for _ in range(future_steps):
    input_seq = input_seq.reshape(1, 90, 1)  # تبدیل به ابعاد مورد انتظار GRU
    pred = model_gru.predict(input_seq)  # پیش‌بینی مقدار جدید
    future_predictions.append(pred[0, 0])  # ذخیره پیش‌بینی
    pred_reshaped = pred.reshape(1, 1, 1)  # تطابق ابعاد با input_seq
    input_seq = np.append(input_seq[:, 1:, :], pred_reshaped, axis=1)  # بروزرسانی sequence

future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# رسم پیش‌بینی GRU
plt.figure(figsize=(10, 6))
plt.plot(range(future_steps), future_predictions, label='Predicted (GRU)', color='red')
plt.title('GRU Model - 1-Month Ahead Prediction')
plt.xlabel('Days')
plt.ylabel('Closing Price')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
